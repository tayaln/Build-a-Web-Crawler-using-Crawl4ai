# %%
# !pip install "crawl4ai @ git+https://github.com/unclecode/crawl4ai.git"
# Out:
# Collecting crawl4ai@ git+https://github.com/unclecode/crawl4ai.git
#   Cloning https://github.com/unclecode/crawl4ai.git to /tmp/pip-install-2v1r3r6b/crawl4ai_a65151612423406a9d8cd1cb68f9889f
#   Running command git clone --filter=blob:none --quiet https://github.com/unclecode/crawl4ai.git /tmp/pip-install-2v1r3r6b/crawl4ai_a65151612423406a9d8cd1cb68f9889f
#   Resolved https://github.com/unclecode/crawl4ai.git to commit e5e6a34e8097cb5ff72c026b19859b5b98246378
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: aiohttp==3.9.5 in /usr/local/lib/python3.10/dist-packages (from crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (3.9.5)
# Requirement already satisfied: aiosqlite==0.20.0 in /usr/local/lib/python3.10/dist-packages (from crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (0.20.0)
# Requirement already satisfied: beautifulsoup4==4.12.3 in /usr/local/lib/python3.10/dist-packages (from crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (4.12.3)
# Requirement already satisfied: fastapi==0.111.0 in /usr/local/lib/python3.10/dist-packages (from crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (0.111.0)
# Requirement already satisfied: html2text==2024.2.26 in /usr/local/lib/python3.10/dist-packages (from crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (2024.2.26)
# Requirement already satisfied: httpx==0.27.0 in /usr/local/lib/python3.10/dist-packages (from crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (0.27.0)
# Requirement already satisfied: litellm==1.40.17 in /usr/local/lib/python3.10/dist-packages (from crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (1.40.17)
# Requirement already satisfied: pydantic==2.7.4 in /usr/local/lib/python3.10/dist-packages (from crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (2.7.4)
# Requirement already satisfied: python-dotenv==1.0.1 in /usr/local/lib/python3.10/dist-packages (from crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (1.0.1)
# Requirement already satisfied: requests==2.32.3 in /usr/local/lib/python3.10/dist-packages (from crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (2.32.3)
# Requirement already satisfied: rich==13.7.1 in /usr/local/lib/python3.10/dist-packages (from crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (13.7.1)
# Requirement already satisfied: selenium==4.23.1 in /usr/local/lib/python3.10/dist-packages (from crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (4.23.1)
# Requirement already satisfied: uvicorn==0.30.1 in /usr/local/lib/python3.10/dist-packages (from crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (0.30.1)
# Requirement already satisfied: pillow==10.3.0 in /usr/local/lib/python3.10/dist-packages (from crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (10.3.0)
# Requirement already satisfied: slowapi==0.1.9 in /usr/local/lib/python3.10/dist-packages (from crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (0.1.9)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.9.5->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.9.5->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.9.5->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.9.5->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.9.5->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (1.11.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.9.5->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (4.0.3)
# Requirement already satisfied: typing_extensions>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiosqlite==0.20.0->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4==4.12.3->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (2.6)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in /usr/local/lib/python3.10/dist-packages (from fastapi==0.111.0->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (0.37.2)
# Requirement already satisfied: fastapi-cli>=0.0.2 in /usr/local/lib/python3.10/dist-packages (from fastapi==0.111.0->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (0.0.5)
# Requirement already satisfied: jinja2>=2.11.2 in /usr/local/lib/python3.10/dist-packages (from fastapi==0.111.0->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (3.1.4)
# Requirement already satisfied: python-multipart>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from fastapi==0.111.0->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (0.0.9)
# Requirement already satisfied: ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from fastapi==0.111.0->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (5.10.0)
# Requirement already satisfied: orjson>=3.2.1 in /usr/local/lib/python3.10/dist-packages (from fastapi==0.111.0->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (3.10.7)
# Requirement already satisfied: email_validator>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from fastapi==0.111.0->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (2.2.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx==0.27.0->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx==0.27.0->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx==0.27.0->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (1.0.5)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx==0.27.0->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (3.8)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx==0.27.0->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (1.3.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from litellm==1.40.17->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (8.1.7)
# Requirement already satisfied: ijson in /usr/local/lib/python3.10/dist-packages (from litellm==1.40.17->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (3.3.0)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /usr/local/lib/python3.10/dist-packages (from litellm==1.40.17->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (8.4.0)
# Requirement already satisfied: openai>=1.27.0 in /usr/local/lib/python3.10/dist-packages (from litellm==1.40.17->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (1.44.1)
# Requirement already satisfied: tiktoken>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from litellm==1.40.17->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (0.7.0)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.10/dist-packages (from litellm==1.40.17->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (0.19.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic==2.7.4->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /usr/local/lib/python3.10/dist-packages (from pydantic==2.7.4->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (2.18.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests==2.32.3->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests==2.32.3->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (2.0.7)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich==13.7.1->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich==13.7.1->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (2.16.1)
# Requirement already satisfied: trio~=0.17 in /usr/local/lib/python3.10/dist-packages (from selenium==4.23.1->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (0.26.2)
# Requirement already satisfied: trio-websocket~=0.9 in /usr/local/lib/python3.10/dist-packages (from selenium==4.23.1->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (0.11.1)
# Requirement already satisfied: websocket-client~=1.8 in /usr/local/lib/python3.10/dist-packages (from selenium==4.23.1->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (1.8.0)
# Requirement already satisfied: limits>=2.3 in /usr/local/lib/python3.10/dist-packages (from slowapi==0.1.9->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (3.13.0)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.10/dist-packages (from uvicorn==0.30.1->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (0.14.0)
# Requirement already satisfied: dnspython>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from email_validator>=2.0.0->fastapi==0.111.0->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (2.6.1)
# Requirement already satisfied: typer>=0.12.3 in /usr/local/lib/python3.10/dist-packages (from fastapi-cli>=0.0.2->fastapi==0.111.0->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (0.12.5)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=6.8.0->litellm==1.40.17->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (3.20.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.11.2->fastapi==0.111.0->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (2.1.5)
# Requirement already satisfied: deprecated>=1.2 in /usr/local/lib/python3.10/dist-packages (from limits>=2.3->slowapi==0.1.9->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (1.2.14)
# Requirement already satisfied: importlib-resources>=1.3 in /usr/local/lib/python3.10/dist-packages (from limits>=2.3->slowapi==0.1.9->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (6.4.5)
# Requirement already satisfied: packaging<25,>=21 in /usr/local/lib/python3.10/dist-packages (from limits>=2.3->slowapi==0.1.9->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (24.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich==13.7.1->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (0.1.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai>=1.27.0->litellm==1.40.17->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (1.7.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai>=1.27.0->litellm==1.40.17->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (0.5.0)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai>=1.27.0->litellm==1.40.17->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (4.66.5)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx==0.27.0->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (1.2.2)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken>=0.7.0->litellm==1.40.17->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (2024.5.15)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium==4.23.1->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (2.4.0)
# Requirement already satisfied: outcome in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium==4.23.1->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (1.3.0.post0)
# Requirement already satisfied: wsproto>=0.14 in /usr/local/lib/python3.10/dist-packages (from trio-websocket~=0.9->selenium==4.23.1->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from urllib3[socks]<3,>=1.26->selenium==4.23.1->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (1.7.1)
# Requirement already satisfied: httptools>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.12.0->fastapi==0.111.0->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (0.6.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.12.0->fastapi==0.111.0->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (6.0.2)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.12.0->fastapi==0.111.0->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (0.20.0)
# Requirement already satisfied: watchfiles>=0.13 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.12.0->fastapi==0.111.0->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (0.24.0)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.12.0->fastapi==0.111.0->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (13.0.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from tokenizers->litellm==1.40.17->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (0.24.6)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated>=1.2->limits>=2.3->slowapi==0.1.9->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (1.16.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm==1.40.17->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (3.16.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm==1.40.17->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (2024.6.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.12.3->fastapi-cli>=0.0.2->fastapi==0.111.0->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (1.5.4)

# %%
from crawl4ai import WebCrawler

# %%
# Create an instance of WebCrawler
crawler = WebCrawler()
# Out:
# [LOG] 🚀 Initializing LocalSeleniumCrawlerStrategy

# %%
# Warm up the crawler (load necessary models)
crawler.warmup()
# Out:
# [LOG] 🌤️  Warming up the WebCrawler
# [LOG] 🌞 WebCrawler is ready to crawl

# %%
# Run the crawler on a URL
result = crawler.run(
    url = "https://www.aimletc.com/online-instructor-led-ai-llm-coaching-for-it-technical-professionals/"
)

# Print the extracted content
print(result.markdown)
# Out:
# [LOG] 🚀 Crawling done for https://www.aimletc.com/online-instructor-led-ai-llm-coaching-for-it-technical-professionals/, success: True, time taken: 5.214460372924805 seconds
# [LOG] 🚀 Content extracted for https://www.aimletc.com/online-instructor-led-ai-llm-coaching-for-it-technical-professionals/, success: True, time taken: 0.38730597496032715 seconds
# [LOG] 🔥 Extracting semantic blocks for https://www.aimletc.com/online-instructor-led-ai-llm-coaching-for-it-technical-professionals/, Strategy: NoExtractionStrategy
# [LOG] 🚀 Extraction done for https://www.aimletc.com/online-instructor-led-ai-llm-coaching-for-it-technical-professionals/, time taken: 0.3984522819519043 seconds.
# Skip to content
#
# No results
#
#   * Teacher
#   * AI+LLM Coaching
#     * AI + GenAI with coding
#     * AI + GenAI minus coding
#     * Weekend Course Gen AI (with coding)
#     * Weekend Course Gen AI (minus coding)
#   * Pricing
#   * Build AI Tools Yourself
#     * How DSPy framework is replacing Prompt Engineering
#     * AI Agent (ChatGPT + Google)
#     * Access GPT4o using API
#     * Multi AI Agent System (Debate)
#     * LLM Chatbot with GCP
#     * Chat with your PDF
#     * AI Video generation tool
#     * YouTube video summarizer
#     * Multi AI Agent System to Customize Resume
#   * Free Courses
#     * AI
#       * Intro to ML and AI
#       * Supervised Learning
#       * UnSupervised Learning
#       * Reinforcement Learning
#       * Neural Networks
#       * Computer Vision
#       * Generative AI
#     * LLM
#       * Prompt Engineering
#       * Intro to LLMs
#       * Retrieval Augmented Generation
#       * Semantic Search
#       * Finetuning LLM
#       * Multi Modality
#       * LLM Agents
#     * Management
#       * Developer frameworks
#       * AI Regulations
#       * LLM Lingo
#       * LLM ApplicationSecurity
#
# AI + LLM courses & coaching specifically designed for senior IT
# professionals!!
#
# ![\\"AI](\\"https://www.aimletc.com/wp-
# content/uploads/2023/08/1692714068314.png\\")
#
#   * Teacher
#   * AI+LLM Coaching
#     * AI + GenAI with coding
#     * AI + GenAI minus coding
#     * Weekend Course Gen AI (with coding)
#     * Weekend Course Gen AI (minus coding)
#   * Pricing
#   * Build AI Tools Yourself
#     * How DSPy framework is replacing Prompt Engineering
#     * AI Agent (ChatGPT + Google)
#     * Access GPT4o using API
#     * Multi AI Agent System (Debate)
#     * LLM Chatbot with GCP
#     * Chat with your PDF
#     * AI Video generation tool
#     * YouTube video summarizer
#     * Multi AI Agent System to Customize Resume
#   * Free Courses
#     * AI
#       * Intro to ML and AI
#       * Supervised Learning
#       * UnSupervised Learning
#       * Reinforcement Learning
#       * Neural Networks
#       * Computer Vision
#       * Generative AI
#     * LLM
#       * Prompt Engineering
#       * Intro to LLMs
#       * Retrieval Augmented Generation
#       * Semantic Search
#       * Finetuning LLM
#       * Multi Modality
#       * LLM Agents
#     * Management
#       * Developer frameworks
#       * AI Regulations
#       * LLM Lingo
#       * LLM ApplicationSecurity
#
# LEARN AI FASTER
#
# Search
#
# AI + LLM courses & coaching specifically designed for senior IT
# professionals!!
#
# ![\\"AI](\\"...\\")
#
# Menu
#
# LEARN AI FASTER
#
# # AI + LLM Coaching (with coding) for Senior Technical professionals
#
#   * ![\\"Nikhilesh](\\"https://secure.gravatar.com/avatar/6f87c78af1e171f2dab169f537214351?s=50&d=mm&r=g\\")Nikhilesh Tayal
#   * March 25, 2024
#   * AI, ML, Gen AI, LLM Coaching
#   * 3 Comments
#
# ![\\"\\"](\\"https://www.aimletc.com/wp-content/uploads/2024/03/nus-ai-
# jpg.webp\\")
#
# Share it with your senior IT friends and colleagues
#
# Reading Time:  2 minutes
#
# ## Practical, Relevant, End-to-End and Short AI + LLM Course and Coaching
#
# Online coaching on Artificial Intelligence, Generative AI and Large Language
# Models to build a career in the AI domain or implement AI in your business.
#
# ## Who will benefit most from this course?
#
# Senior IT Professionals like Tech Product Managers, Senior Engineers, Tech
# Entrepreneurs, CTOs, DevOps Professionals etc who want to learn AI + LLM
# quickly and easily.
#
# ## Course Curriculum
#
# ![\\"\\"](\\"https://www.aimletc.com/wp-content/uploads/2024/03/AI-with-
# coding-11.09-1024x552.png\\") ![\\"\\"](\\"https://www.aimletc.com/wp-
# content/uploads/2024/03/AI-with-coding-11.09-2-1-1024x483.png\\")
#
# ## How is the course Practical?
#
# You will get access to the following Hands-on labs and you will also make the
# following working AI/ ML/ LLM Applications and tools
#
# ### Hands-On Labs
#
#   1. Pandas Lab
#   2. Machine Learning Lab
#   3. Deep Learning Lab
#   4. Computer Vision Lab
#   5. NLP Lab
#   6. Building LLM Applications Lab
#   7. Promot Engineering for Developers Lab
#   8. LangChain Lab
#   9. Function calling Lab
#   10. Monitoring Langchain application with Langsmith
#   11. RAG Lab
#   12. Fine Tuning using Gradient
#   13. Multi AI Agent using open-sourced LLM
#   14. Deploying LLM – Deep Infra
#   15. Deploying LLM – Replicate
#   16. Deploying LLM – Runpod
#   17. LM Scorer (Evaluation of LLMs)
#   18. Deploying on AWS Sagemaker
#   19. Deploying Langchain application with LangServe
#   20. Multi AI Agent Debate using AutoGen (Delhi vs Mumbai)
#   21. Langgraph – Intro Lab
#   22. DSPy framework demo
#   23. Small Language Models Lab
#   24. Quantize any LLM Lab
#
# ### Practical AI Tools/ Applications that you will build
#
#   1. ML Classification model
#   2. Image Segmentation
#   3. Text-to-Voice
#   4. AI video Generation
#   5. Image Generation using Open Source models on Huggingface
#   6. Calling any OpenSource LLMs
#   7. GPT4 – API calling
#   8. LLM Chatbot
#   9. Multi-lingual Text Summarization
#   10. YouTube video Summarization Tool
#   11. Monitoring LLM using LangSmith
#   12. Chat with your Own PDF
#   13. LLM Chatbot for your proprietary data using the Google Cloud Platform
#   14. Fine-tune Gemma models in Keras using LoRA
#   15. ChatGPT + Google Search
#   16. LLM Medical Agent
#   17. Gradio Application
#   18. Streamlit Application using Gemini Pro
#   19. Evaluation of LLMs using Giskard
#   20. AI Voice Assistant App using Multimodal LLM “Llava” and Whisper
#   21. Multi Agent System to Tailor Job Applications
#   22. LangGraph -Multi AI Agent System for coding
#   23. Build a Web Crawler using Crawl4ai
#
# ## Course Duration
#
# Total (Classroom coaching) – 24 hours + 4 hours (for advanced learners)*
#
# 1-hour session per day
#
# Weekend batch – 12 weeks
#
# Weekday batch – 6 weeks
#
# It’s a short program but a rigorous one
#
# Apart from these coaching sessions, you must spend around 2-3 hours extra
# doing practical/hands-on exercises.
#
# *Price would be extra on a pro-rata basis
#
# ## Do you provide OpenAI credits?
#
# Yes, we are affiliated with Microsoft for Startup Founders Hub and we have
# received OpenAI’s credits. We pass these credits to our learners to do
# practical exercises.
#
# ## Course Mode
#
# Instructor-led Interactive Online Classes.
#
# ## Pre-requisite
#
# Python (the ability to read code in Python)
#
# (Most of the code in the Lab and Practical applications are already written)
#
# ## Who is the teacher?
#
# Nikhilesh Tayal – https://www.aimletc.com/about-me-nikhilesh-tayal/
#
# LinkedIn – https://www.linkedin.com/in/nikhileshtayal/
#
# ## Price
#
# Check here – https://www.aimletc.com/ai-ml-etc-course-offerings-pricing/
#
# ## More FAQs
#
# Check – https://www.aimletc.com/faqs-ai-courses-for-senior-it-professionals/
#
# For any further questions, please drop an email at nt(at)aimletc.com
#
# Featured Image Source
#
# Post Views: 1,331
#
# Share it with your senior IT friends and colleagues
#
# ![\\"Nikhilesh](\\"...\\")
#
# #####  Nikhilesh Tayal
#
# Articles: 66
#
# ![\\"Does](\\"...\\")
#
# Previous Post Does learning Artificial Intelligence require coding? Can a non-
# technical person learn AI?
#
# Next Post Top 16 AI tools for Senior professionals and Entrepreneurs (2024
# Edition)
#
# ![\\"AI](\\"...\\")
#
# ## Learn AI and LLM in instructor-led live classes to join the likes of
# Microsoft, Nvidia, Infosys, Jio, Oracle, Aricent, Accenture & more !!
#
# Name
#
# Email
#
# ##### Connect with me on LinkedIn
#
#   * LinkedIn
#
# ## Top Articles
#
#   * ![\\"GPT4o\\"](\\"https://www.aimletc.com/wp-content/uploads/wordpress-popular-posts/1452-featured-75x75.webp\\") How to use the latest GPT-4o model using OpenAI’s API and free credits
#   * ![\\"\\"](\\"https://www.aimletc.com/wp-content/uploads/wordpress-popular-posts/670-featured-75x75.webp\\") AI + LLM Coaching (with coding) for Senior Technical professionals
#   * ![\\"Nikhilesh](\\"https://www.aimletc.com/wp-content/uploads/wordpress-popular-posts/270-featured-75x75.jpg\\") About Me – Nikhilesh Tayal
#   * ![\\"Nikhilesh](\\"https://www.aimletc.com/wp-content/uploads/wordpress-popular-posts/60-featured-75x75.jpg\\") How I learned AI as a non-technical person in 4 months for free.
#
# ![\\"\\"](\\"https://www.aimletc.com/wp-content/uploads/2024/06/WhatsApp-
# Image-2024-06-10-at-11.52.53-AM-1-530x1024.jpeg\\")
#
# ![\\"\\"](\\"https://www.aimletc.com/wp-content/uploads/2024/06/WhatsApp-
# Image-2024-06-10-at-11.52.53-AM-536x1024.jpeg\\")
#
# ![\\"\\"](\\"https://www.aimletc.com/wp-content/uploads/2024/04/WhatsApp-
# Image-2024-04-16-at-10.07.54-PM-995x1024.jpeg\\")
#
# ![\\"\\"](\\"https://www.aimletc.com/wp-content/uploads/2024/04/WhatsApp-
# Image-2024-04-16-at-10.07.54-PM-1-790x1024.jpeg\\")
#
# ![\\"\\"](\\"https://www.aimletc.com/wp-content/uploads/2024/02/Feedback-
# Kanti-459x1024.webp\\")
#
# ![\\"\\"](\\"https://www.aimletc.com/wp-
# content/uploads/2023/09/1694270939266-702x1024.jpg\\")
#
# ![\\"\\"](\\"https://www.aimletc.com/wp-
# content/uploads/2023/09/1694270939270-780x1024.jpg\\")
#
# ###  Related Posts
#
# ![\\"\\"](\\"...\\")
#
# #### AI + LLM Coaching (without coding) for Senior Functional Professionals
#
#   * May 25, 2024
#
# ![\\"Weekend](\\"...\\")
#
# #### Weekend Crash Course on AI + Gen AI with coding
#
#   * May 21, 2024
#
# ![\\"Weekend](\\"...\\")
#
# #### Weekend Crash Course on AI + Gen AI (without coding)
#
#   * May 7, 2024
#
# ##### AI ML etc.
#
#   * About Us
#   * Contact Us
#   * Why the world needs “AI ML etc.”?
#   * FAQs
#
# ##### Connect with me on LinkedIn
#
#   * LinkedIn
#
# ##### Contact info
#
# ![\\"\\"](\\"...\\")
# nt(at)aimletc(dot) com
#
# ![\\"\\"](\\"...\\")
# 9024305296
#
# Copyright © 2024 @ WinSaga Edutech Private Limited (CIN -
# U85500RJ2024PTC093924)
